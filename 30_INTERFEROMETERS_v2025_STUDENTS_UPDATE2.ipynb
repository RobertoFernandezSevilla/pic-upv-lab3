# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 3. Interferometers I - MZI

# %% [markdown]
# Today we will work on the design and modeling of an **Mach-Zenhder Interferometer (MZI)** used in integrated photonic circuits. We will perform simulations that will allow us to understand how it operates.

# %% [markdown]
# ## 0.1 General libraries

# %%
import gdsfactory as gf
import jax
import jax.example_libraries.optimizers as opt
import jax.numpy as jnp
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

import numpy as np
import sax ##simulación circuitos dotónicos
from gdsfactory.generic_tech import get_generic_pdk
from scipy import constants
from scipy.constants import c
from scipy.interpolate import interp1d

import gplugins.sax as gs
from gplugins.common.config import PATH
# Out:
# /tmp/ipykernel_2444/3261580824.py:10: DeprecationWarning: The 'gdsfactory.generic_tech' module is deprecated and will be removed in a future version. Please update your imports to use 'gdsfactory.gpdk' instead:
#   from gdsfactory.gpdk import LAYER, LAYER_STACK, get_generic_pdk
# Or for submodules:
#   from gdsfactory.gpdk.layer_map import LAYER
#   from gdsfactory.gpdk.layer_stack import LAYER_STACK
#   from gdsfactory.generic_tech import get_generic_pdk

# %% [markdown]
# ## 1. MZI modeling
# Let's compute the transfer function of a MZI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)

## SiN cross-section ## para la pltaforma de sin 
# SiN_clad = np.loadtxt('SiN-h300nm-w1000nm-Cladding.txt', skiprows=1, delimiter='\t')
# SiN_wat = np.loadtxt('SiN-h300nm-w1000nm-Water.txt', skiprows=1, delimiter='\t')

# wvl0 = SiN_clad[:, 0]
# neffu0 = SiN_clad[:, 3] #balanced configuration // (neff TE mode)
# neffd0 = SiN_wat[:, 3] #balanced configuration // (neff TE mode)

# interp_neffu = interp1d(wvl0, neffu0, kind='cubic')  # Cubic interpolation for smoothness
# interp_neffd = interp1d(wvl0, neffd0, kind='cubic')
# wvl = np.linspace(wvl0.min(), wvl0.max(), 1000)
# neffu = interp_neffu(wvl)
# neffd = interp_neffd(wvl)

# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# WARNING:2026-03-02 12:31:56,928:jax._src.xla_bridge:876: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
#Tenemos diferente longitud

# %% [markdown]
# **Assesment 1.** Please, provide one example of each one of the configurations studied during MZI lecture:
# 1. Balenced configuration
# 2. Unbalanced configuration
#   1.   Phase difference
#   2.   Delay imbalance

# %%
#Balenced configuration - 1 
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 25; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Balenced configuration - 2
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 25; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.7)
K_b = np.full(wvl.shape, 0.3)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# WARNING:2026-03-02 15:19:06,366:jax._src.xla_bridge:876: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
#Balenced configuration - 3
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 25; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0.1; #null excess loss
gamma_b = 0.1; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.7)
K_b = np.full(wvl.shape, 0.3)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Unbalenced configuration - 1 y 2 y 3
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3]+0.05#balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 25; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Unbalenced configuration - 1 y 2 y 3
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3]+0.2#balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 25; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Unbalenced configuration -delay -1
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 25; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Unbalenced configuration -delay -1
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 35; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
#Unbalenced configuration -delay -1
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 15; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %%
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t')

wvl = SOI[:,0]       
neff = SOI[:,3]       

#calculamos el indice efectivo
dn_dlambda = np.gradient(neff, wvl)
ng = neff - wvl * dn_dlambda


lambda0 = 1.55 

idx = np.argmin(np.abs(wvl - lambda0))

ng0 = ng[idx] # para obtener la posición de la lambda central

# FSR de 40nm
FSR = 0.04   

#Calculamos la diferencia de longitud
DeltaL = lambda0**2 / (ng0 * FSR)

print("índice de grupo=", ng0)
print("ΔL necesario =", DeltaL, "um")
# Out:
# Group index ng = 4.29327
# Required path difference ΔL = 13.989919105949546 um

# %%
#Unbalenced configuration -delay -1
### Waveguides configuration ###

## Propagation parameters

## SOI cross-section ##
SOI = np.loadtxt('SOI-w450-h220-clad600.txt', skiprows=1, delimiter='\t') #tenemosvarios txt con los datods 

wvl = SOI[:, 0]
# como ponemos los dos brazos con el mismo indice es balanceado
neffu = SOI[:, 3] #balanced configuration // (neff TE mode) # sacamos datos del archivo que nos interesan 
neffd = SOI[:, 3] #balanced configuration // (neff TE mode)



# Propagation loss
#sin périddas de propagacion
alphau = 0 #losless case [dB/um]
alphad = 0; #losless case [dB/um]
alphau_np = (jnp.log(10.0)/10.0) * alphau   # neper/um
alphad_np = (jnp.log(10.0)/10.0) * alphad   # neper/um

# Path length
#diferencia de longitud entre los brazos
Lu = 5+13.989919105949546; # um
Ld = 5; # um

betau = (2*jnp.pi/wvl)*neffu-1j*alphau_np
betad = (2*jnp.pi/wvl)*neffd-1j*alphad_np

Delta_phi_ud = betau*Lu - betad*Ld

### Couplers configuration ###
# Excess loss
#sin pérdidas de exceso
gamma_a = 0; #null excess loss
gamma_b = 0; #null excess loss

# Coupling constant
#el 50% de la potencia irá a cada uno de los brazos. 
K_a = np.full(wvl.shape, 0.5)
K_b = np.full(wvl.shape, 0.5)

# MZI transfer function (h22 & h21)

#  h_22(wvl)
h_22 = (np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*(( np.sqrt((1 - K_a) * (1 - K_b)) * np.exp(-1j * Delta_phi_ud))-(np.sqrt(K_a * K_b))) # son las ecuaciones de arriba 

#  h_21(wvl)
h_21 = (1j * np.sqrt((1 - gamma_a) * (1 - gamma_b)))*(np.exp(-1j * betad * Ld))*((np.sqrt(K_b * (1 - K_a)) * np.exp(-1j * Delta_phi_ud))+(np.sqrt(K_a * (1 - K_b))))
#en potencia
H21 = np.abs(h_21) ** 2
H22 = np.abs(h_22) ** 2

# Plot
color = cm.rainbow(np.linspace(0, 1, 10))

plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Assesment 2.** Taking into account the n_{eff} values for the SOI cross-section, what would be the path difference ($\Delta L$ = $L_u$ - $L_d$) needed to obtain a Free Spectral Range of 40 nm? Introduce the obtained value in the model to check the MZI response. Hint: We assume 1550 nm as the central design wavelength ($\lambda _0$=1550 nm).

# %% [markdown]
# ## 2. MZI simulation implemented with SAX
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#ahora trabajaremos con la s matrix.
#tendremos dos acopladores y dos modelos de guia recta.

# %% [markdown]
# ### 2.1 Components S matrix

# %%
# Waveguide Model
##
def waveguide(wl=1.55, neff=1.6072, length=10.0, loss=0.0) -> sax.SDict:
    phase = 2 * jnp.pi * neff * length / wl ##termino de fase
    transmission = 10 ** (-loss * length / 20) * jnp.exp(1j * phase) # loss(dB/um)
    wg_dict = sax.reciprocal(
        {
            ("in0", "out0"): transmission, ##reciproco porque no importa si entro por in0 y salgo por out0, o entro por out0 y salgo por in0
        }
    )
    return wg_dict


# Coupler Model

def coupler(coupling=0.5) -> sax.SDict:
    kappa = coupling**0.5 #la relacion entre los puertos cruzados, 
    # in1 out 1
    # in0 out 1
    # k nos dice in0/out1 , y in1/out0
    tau = (1 - coupling) ** 0.5
    coupler_dict = sax.reciprocal( # aqui definimos los puertos. 
        {
            ("in0", "out0"): tau, ##bar 
            ("in0", "out1"): kappa * np.exp(-1j * np.pi / 2.0), #si cruzo un puerto meto un desfase de pi/2
            ("in1", "out0"): kappa * np.exp(-1j * np.pi / 2.0),
            ("in1", "out1"): tau,
        }
    )
    return coupler_dict

# %% [markdown]
# ### 2.2 MZI SAX Circuit Model

# %%
# MZI
##para ver las conexiones bien ver el dibujo de Ports-MZI connection-draw.pdf
mzi, info = sax.circuit(
    netlist={ #todo lo que define mi componente, 
        "instances": {
            "coup_a": "coupler", #acoplador - utilizo el modelo de coupler
            "wvg_u": "waveguide",#guia de onda arriba - utilizo el modelo de waveguide
            "wvg_d": "waveguide",#guia de onda abajo
            "coup_b": "coupler", #acoplador
        },
        "connections": {
            "coup_a,out0": "wvg_d,in0", #  el out0 de mi acoplador a va a al in0 de mi waveguide de abajo
            "wvg_d,out0": "coup_b,in0",
            "coup_a,out1": "wvg_u,in0",
            "wvg_u,out0": "coup_b,in1",
        },
        "ports": {
            "in0": "coup_a,in0",
            "in1": "coup_a,in1",
            "out0": "coup_b,out0",
            "out1": "coup_b,out1",
        },
    },
    models={
        "coupler": coupler,
        "waveguide": waveguide,
    },
)

# %% [markdown]
# ### 2.3. MZI Modeling
# **Assesment 3**: Now, we are going to implement the design parameters in the MZI model developed in SAX and compare the response obtained with that simulated by mathematical formulation.
#
# This will help us to identify any error in the definition of the SAX model single components.
#
# In order to implement the SAX model, take as example the following lines:
#
#     mzi_test = mzi(wl=wl,
#                 coup_a = ...
#                 wvg_d={"length": l_d, "neff": ...},
#                 wvg_u={"length": l_u, "neff": ...},
#                 coup_b = ... )
#
#     H00 = mzi_test["in0", "out0"]

# %% [markdown]
# **Assessment 4.** Designing an MZI for filtering at a specific wavelength. Calculate and adjust the arm lengths to configure the MZI to have a maximum transmission at 1550 nm.
#
# **Assessment 5.** Let's see how the response of the MZI variates with the effective index. Vary the effective index of one of the arms and analyze how the spectrum shifts. To do this, you can use the data provided in the .txt files entitled ‘SiN’.
# Can you give an example of an application where this configuration is used?
#
# **Assessment 6.** Explore how cascading two MZIs affects the transmission spectrum. To do so, design a system in which two MZIs are cascaded. Simulate and observe the spectrum, explaining how the transmission peaks behave.

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": Lu, "loss":alphau},
            wvg_d={"wl":wvl, "neff":neffd, "length": Ld, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %%
# Waveguide Model
##
def waveguide(wl=1.55, neff=1.6072, length=10.0, loss=0.0) -> sax.SDict:
    phase = 2 * jnp.pi * neff * length / wl ##termino de fase
    transmission = 10 ** (-loss * length / 20) * jnp.exp(1j * phase) # loss(dB/um)
    wg_dict = sax.reciprocal(
        {
            ("in0", "out0"): transmission, ##reciproco porque no importa si entro por in0 y salgo por out0, o entro por out0 y salgo por in0
        }
    )
    return wg_dict


# Coupler Model

def coupler(coupling=0.5) -> sax.SDict:
    kappa = coupling**0.5 #la relacion entre los puertos cruzados, 
    # in1 out 1
    # in0 out 1
    # k nos dice in0/out1 , y in1/out0
    tau = (1 - coupling) ** 0.5
    coupler_dict = sax.reciprocal( # aqui definimos los puertos. 
        {
            ("in0", "out0"): tau, ##bar 
            ("in0", "out1"): kappa * np.exp(-1j * np.pi / 2.0), #si cruzo un puerto meto un desfase de pi/2
            ("in1", "out0"): kappa * np.exp(-1j * np.pi / 2.0),
            ("in1", "out1"): tau,
        }
    )
    return coupler_dict

# %%
# MZI
##para ver las conexiones bien ver el dibujo de Ports-MZI connection-draw.pdf
mzi, info = sax.circuit(
    netlist={ #todo lo que define mi componente, 
        "instances": {
            "coup_a": "coupler", #acoplador - utilizo el modelo de coupler
            "wvg_u": "waveguide",#guia de onda arriba - utilizo el modelo de waveguide
            "wvg_d": "waveguide",#guia de onda abajo
            "coup_b": "coupler", #acoplador
        },
        "connections": {
            "coup_a,out0": "wvg_d,in0", #  el out0 de mi acoplador a va a al in0 de mi waveguide de abajo
            "wvg_d,out0": "coup_b,in0",
            "coup_a,out1": "wvg_u,in0",
            "wvg_u,out0": "coup_b,in1",
        },
        "ports": {
            "in0": "coup_a,in0",
            "in1": "coup_a,in1",
            "out0": "coup_b,out0",
            "out1": "coup_b,out1",
        },
    },
    models={
        "coupler": coupler,
        "waveguide": waveguide,
    },
)

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": 25, "loss":alphau},
            wvg_d={"wl":wvl, "neff":neffd, "length": 5, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
#plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
#plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": 30, "loss":alphau},
            wvg_d={"wl":wvl, "neff":neffd, "length": 5, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
#plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
#plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": Lu, "loss":alphau},
            wvg_d={"wl":wvl, "neff":neffd, "length": Ld, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
#plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
#plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": Lu, "loss":alphau},
            wvg_d={"wl":wvl, "neff":1.983501353, "length": Ld, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
#plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
#plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()

# %%
mzi_test = mzi(wl=wvl,
            coup_a={"coupling":K_a},
            wvg_u={"wl":wvl, "neff":neffu, "length": Lu, "loss":alphau},
            wvg_d={"wl":wvl, "neff":1.3, "length": Ld, "loss":alphad},
            coup_b={"coupling":K_b},
            )

h00 = mzi_test["in0", "out0"]
h01 = mzi_test["in0", "out1"]
h11 = mzi_test["in1", "out1"]
h10 = mzi_test["in1", "out0"]


# Plot
plt.figure()
plt.plot(wvl, np.abs(h11)**2, linestyle="-", color=color[8], label=f"h11")
plt.plot(wvl, np.abs(h10)**2, linestyle="--", color=color[8], label=f"h10")
#plt.plot(wvl, H22, linestyle='-', color=color[1], label='H22')
#plt.plot(wvl, H21, linestyle='--', color=color[1], label='H21')
plt.xlabel('Wvl (um)')
plt.ylabel('|H|')
plt.title('MZI Transfer function')
plt.grid(True)
plt.show()
